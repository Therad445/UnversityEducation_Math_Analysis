# %%
a=1j
print(a**2)
z=(3-1j)*(2+4j)
print(z)
b = z/2j
print(b)
# Out:
# (-1+0j)
# (10+10j)
# (5-5j)

# %%
#Task 1

# %%
import numpy as np
z = (2+3j)*(3-1j)
print(z)
print((1-1j)**3-(1+1j)**3)
n = np.arange(1,9)
print(1j**n)
print((2-3j)/(1+4j)+1/(4-1j))
# Out:
# (9+7j)
# -4j
# [ 0.+1.j -1.+0.j -0.-1.j  1.+0.j  0.+1.j -1.+0.j -0.-1.j  1.+0.j]
# (-0.35294117647058826-0.5882352941176471j)

# %%
#Task 2

# %%
import numpy as np
t = pow(3,0.5)
z1 = complex(1,t)
z2 = complex(t,1)
print(z1 * np.conj(z2))
print((np.conj(z1)/z2)**2)
# Out:
# (3.4641016151377544+1.9999999999999996j)
# (-1-0j)

# %%
#Task 3

# %%
z1 = (4-5j)*(5+6j)
z2 = (1+1j)**15
print(np.real(z1), np.imag(z1),np.abs(z1), np.angle(z1), np.conj(z1))
print(np.real(z2), np.imag(z2),np.abs(z2), np.angle(z2), np.conj(z2))
# Out:
# 50.0 -1.0 50.00999900019995 -0.01999733397315053 (50+1j)
# 128.0 -128.0 181.01933598375618 -0.7853981633974483 (128+128j)

# %%
import matplotlib.pyplot as plt
x = np.array([2+3j, 2-3j, -2+3j, -2-3j])
plt.plot()
plt.scatter(np.real(x),np.imag(x), marker="*", color="green", s=30)
plt.axis('equal')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
plt.title('Complex numbers')
plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
plt.show()

# %%
x = np.array([2+3j, 2-3j, -2+3j, -2-3j])
orig = np.zeros(4)
plt.plot()
q = plt.quiver(orig,orig, np.real(x), np.imag(x), angles='xy', scale_units='xy', scale=1, color="green")
plt.axis([-4,4,-4,4])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
plt.title('Complex numbers')
plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
plt.show()

# %%
#Task 4

# %%
import matplotlib.pyplot as plt
from sympy import *
import numpy as np
z1 = complex(1,3)
z2 = complex(3,4)
z3 = z1 + z2
z4 = z1 - z2
zer = 0
plt.plot()
x = np.array([z1, z2, z3, z4])
print(x)
q = plt.quiver(zer, zer, np.real(z1), np.imag(z1), angles='xy', scale_units='xy', scale = 1, color="green")
a = plt.quiver(np.real(z1), np.imag(z1), np.real(z2), np.imag(z2), angles='xy', scale_units='xy', scale = 1, color="green")
b = plt.quiver(zer, zer, np.real(z3), np.imag(z3), angles='xy', scale_units='xy', scale = 1, color="red")
c = plt.quiver(zer, zer, -np.real(z2), -np.imag(z2), angles='xy', scale_units='xy', scale = 1, color="green")
c = plt.quiver(zer, zer, -np.real(z1), -np.imag(z1), angles='xy', scale_units='xy', scale = 1, color="green")
e = plt.quiver(-np.real(z1), -np.imag(z1), np.real(z4), np.imag(z4), angles='xy', scale_units='xy', scale = 1, color="blue")


plt.title('z1,  z2,  z1+z2,  z1-z2')
plt.axis([-8,8,-8,8])
plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.grid()
plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
plt.show()
# Out:
# [ 1.+3.j  3.+4.j  4.+7.j -2.-1.j]

# %%
z = 1 +1j
r = np.abs(z)
phi=np.angle(z)
k = np.arange(1,7)
zroot = r**(1/6)*( np.cos((phi+2.0*np.pi*k)/6) + 1j*np.sin((phi+2.0*np.pi*k)/6))
print(zroot)
plt.title('$\sqrt[6]{1+j}$ complex roots')
plt.plot(np.real(zroot), np.imag(zroot), '*g') # если указан тип маркера, но не задан стиль линии, то табличные строки маркером метятся, но друг с другом отрезками прямых не соединяются.
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.axis('equal')
t = np.linspace(0,2*np.pi,100)
plt.plot(r**(1/6)*np.cos(t),r**(1/6)*np.sin(t),':')
plt.grid()
# Out:
# [ 0.40543897+0.97881627j -0.64496027+0.84052858j -1.05039924-0.13828768j
#  -0.40543897-0.97881627j  0.64496027-0.84052858j  1.05039924+0.13828768j]

# %%
# Task 4
z = complex(2*np.sqrt(3), -2)
r = np.abs(z)
angle = np.angle(z)
arg = 2*np.pi*np.arange(1,5)
num = r**0.25*(np.cos((angle + arg)/4) + 1j*np.sin((angle + arg)/4))
plt.plot(np.real(num), np.imag(num), 'b*')
plt.axhline(y=0, color = 'k')
plt.axvline(x=0, color = 'k')
plt.axis('equal')
arr = np.linspace(0,2*np.pi,200)
plt.plot(r**0.25*np.cos(t),r**0.25*np.sin(t), 'r--')
plt.grid()
plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
plt.show()

# %%
#Task 6
z1 = complex(4, np.pi)
z11 = complex(-4, -np.pi)
z2 = complex(6, 5*np.pi)
z22 = complex(-6, -5*np.pi)
zer = np.zeros(4)
num = np.array([z1,z2,z11,z22])
r1 = np.abs(z1)
r2 = np.abs(z2)

plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid()
plt.axvline(x = 0, color = 'k')
plt.axhline(y = 0, color = 'k')
plt.plot(0,0, 'ro')
plt.quiver(0.001,0.001,4, np.pi, color = 'b', scale = 1)
plt.quiver(0.001,0.001,6, 5*np.pi, color = 'g', scale = 1)


plt.title('Arg(z) = $pi$/4, Arg(z) = 5*$pi$/6 ')
plt.show()

# %%
#Task C1
import sympy as sp
print((1+2j)*(1-1j))

print((1-1j)**4 - (1+1j)**4)

k = np.arange(20,41)
print(1j**k)

g = (2+5j)/(1-3j) + 1/(1-1j)
print(g)
print(np.real(g), np.imag(g))

e = sp.symbols('e')
print()
sp.pprint(e**(1j* np.angle(g)))
# Out:
# (3+1j)
# -0j
# [ 1.+0.j  0.+1.j -1.+0.j -0.-1.j  1.+0.j  0.+1.j -1.+0.j -0.-1.j  1.+0.j
#   0.+1.j -1.+0.j -0.-1.j  1.+0.j  0.+1.j -1.+0.j -0.-1.j  1.+0.j  0.+1.j
#  -1.+0.j -0.-1.j  1.+0.j]
# (-0.7999999999999998+1.5999999999999999j)
# -0.7999999999999998 1.5999999999999999
#
#  2.0344439357957⋅ⅈ
# e

# %%
#Task C2
z1 = complex(np.sqrt(3),-1)
z2 = complex(1,np.sqrt(3))
print(z1*np.conj(z2))
print((np.conj(z1)/z2)**2)
# Out:
# -3.9999999999999996j
# (0.5000000000000001-0.8660254037844387j)

# %%
#Task C3
z1 = (5+4j)*(3+2j)
z2 = (1-1j)**13
print(np.real(z1), np.imag(z1), np.abs(z1), np.imag(z1)/np.real(z1), np.conj(z1))
print(np.real(z1), np.imag(z2), np.abs(z2), np.imag(z2)/np.real(z2), np.conj(z2))
# Out:
# 7.0 22.0 23.08679276123039 3.142857142857143 (7-22j)
# 7.0 64.0 90.50966799187809 -1.0 (-64-64j)

# %%
#Task C4
z = complex(-1, -np.sqrt(3))
r = np.abs(z)**(1/6)
angle = np.angle(z)
arg = 2*np.pi*np.arange(1,8)
num = r*(np.cos((angle + arg)/6) + 1j*np.sin((angle + arg)/6))

plt.plot(np.real(num), np.imag(num), 'm-.')
plt.grid()
plt.axhline(y=0, color ='k')
plt.axvline(x=0, color ='k')
plt.axis('equal')
t = np.linspace(0,2*np.pi,200)
plt.plot(r*np.cos(t),r*np.sin(t), 'g--')
plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
plt.show()

# %%
#Task C5

plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
plt.subplot(1,1,1)
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('')
plt.grid()
plt.quiver(0.001,0.001,-1, -0.75*np.pi, color = 'b', scale = 1)
plt.quiver(0.001,0.001,1, -np.pi/3, color = 'y', scale = 1)
plt.title('Arg(z) = -3*$pi$/4, Arg(z) = -$pi$/3')

plt.axvline(x = 0, color = 'k')
plt.axhline(y = 0, color = 'k')
plt.plot(0,0, 'ro')
plt.show()
